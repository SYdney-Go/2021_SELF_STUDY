# %% [markdown]
# # Numpy
# * 흑백 이미지는 2차원의 넘파이 배열로, RGB 이미지는 3차원의 넘파이 배열로 표현할 수 있다.

# %%
### 슬라이싱으로 이미지 만들기
import cv2
import numpy as np

img = np.zeros((120, 120), dtype=np.uint8)

# 가로 조금 + 세로 전체 = 세로로 긴 선
img[25:35, :] = 45 
img[55:65, :] = 115
img[85:95, :] = 160
# 가로 전체 + 세로 조금 = 가로로 긴 선
img[:, 35:45] = 205
img[:, 75:85] = 255


cv2.imshow('Gray', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

img = np.zeros((120, 120, 3), dtype=np.uint8)

# 3차원 BGR 이미지 → 색상도 3차원으로 입력
# 가로 조금 + 세로 전체 = 세로로 긴 선
img[25:35, :] = [255, 0, 0]
img[55:65, :] = [0, 255, 0]
img[85:95, :] = [0, 0, 255]
# 가로 전체 + 세로 조금 = 가로로 긴 선
img[:, 35:45] = [255, 255, 0]
img[:, 75:85] = [255, 0, 255]

cv2.imshow('BGR', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Matplotlib
# ### 1. Plot : 1차원이나 2차원 데이터로 선형 그래프를 그릴 수 있다.

# %%
import matplotlib.pyplot as plt
import numpy as np

# x 값만 있는 1차원 데이터
a = np.array([2, 6, 7, 3, 12, 8, 4, 5])
plt.plot(a)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# x값의 변화에 따라 값이 바뀌는 y로 이루어진 2차원 데이터
x = np.arange(10)
y = x**2

plt.plot(x, y)
plt.show()

# %%
### color 지정
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(10)
y = x ** 2
plt.plot(x, y, 'r')
plt.show()

# %%
### 다양한 스타일 지정
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(10)
f1 = x * 5
f2 = x ** 2
f3 = x ** 2 + x * 2

plt.plot(x, 'r--') # 빨간색 점선
plt.plot(f1, 'g.') # 녹색 원
plt.plot(f2, 'bv') # 파랑색 역삼각형
plt.plot(f3, 'ks') # 검정 네모
plt.show()

# %%
### subplot : 여러 그래프를 한번에 그리기
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(10)

plt.subplot(2, 2, 1) # 2행 2열중에 첫번째
plt.plot(x, x**2)

plt.subplot(2, 2, 2) # 2행 2열중에 두번째
plt.plot(x, x*5)

plt.subplot(223) # 2행 2열중에 세번째
plt.plot(x, np.sin(x))

plt.subplot(224) # 2행 2열중에 네번째
plt.plot(x, np.cos(x))

plt.show()

# %%
###  이미지 표시
import cv2
from matplotlib import pyplot as plt

# cv2는 이미지를 BGR 순으로 읽어온다.
img = cv2.imread('./picture/woman.jpg')

# plt는 이미지를 RGB 순으로 보여준다.
plt.imshow(img)
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('./picture/woman.jpg')

# 마지막 체널(차원)의 전체 순서를 바꿔서 표현
plt.imshow(img[:, :, ::-1]) # img[:,:,2], img[:,:,1], img[:,:0] = img[:,:,0], img[:,:,1], img[:,:,2]
plt.xticks([])
plt.yticks([])
plt.show()

# %%
### 여러 이미지 동시 출력
import matplotlib.pyplot as plt
import numpy as np
import cv2

img1 = cv2.imread('./picture/love1.jpg')
img2 = cv2.imread('./picture/love2.jpg')
img3 = cv2.imread('./picture/love3.png')

plt.subplot(1, 3, 1)
plt.imshow(img1[:, :, ::-1])
plt.xticks([])
plt.yticks([])

plt.subplot(1, 3, 2)
plt.imshow(img2[:, :, ::-1])
plt.xticks([])
plt.yticks([])

plt.subplot(1, 3, 3)
plt.imshow(img3[:, :, ::-1])
plt.xticks([])
plt.yticks([])

plt.show()
